# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math 
import random as rn
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('WeatherTrainingData.csv')
data.drop(labels=['Location','Evaporation', 'WindDir9am', 'WindDir3pm' ,'WindGustDir','Sunshine','row ID', 'RainTomorrow' ], inplace=True, axis=1)
data["Cloud3pm"].fillna(0, inplace = True)
data["Cloud9am"].fillna(0, inplace = True)
data.replace({'RainToday': {"No": 0, 'Yes': 1}},inplace=True)
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)
data = data[:len(data)//2]
data
# Out:
#        MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0         13.4     22.9       0.6           44.0          20.0          24.0
# 1          7.4     25.1       0.0           44.0           4.0          22.0
# 2         17.5     32.3       1.0           41.0           7.0          20.0
# 3         14.6     29.7       0.2           56.0          19.0          24.0
# 4          7.7     26.7       0.0           35.0           6.0          17.0
# ...        ...      ...       ...            ...           ...           ...
# 41899      5.4     13.4       2.0           59.0          24.0          31.0
# 41900      2.1     13.2       2.4           30.0          15.0          15.0
# 41901      4.4     16.5       0.0           48.0          15.0          31.0
# 41902      6.1     14.5       0.4           44.0          11.0          28.0
# 41903      6.1     16.2       0.0           30.0          11.0          19.0
#
# ...

# %%
avgtemp = [0]*len(data)
avgwind = [0]*len(data)
avghumidity = [0]*len(data)
avgpressure = [0]*len(data)
avgclouds = [0]*len(data)

len(avgtemp)
for i in range (len(data)):
    avgtemp[i] = (data.iloc[i]['Temp3pm']+data.iloc[i]['Temp9am'])*0.5
    avgwind[i] = (data.iloc[i]['WindSpeed9am']+data.iloc[i]['WindSpeed3pm'])*0.5
    avghumidity[i]=(data.iloc[i]['Humidity9am']+data.iloc[i]['Humidity3pm'])*0.5
    avgpressure[i]=(data.iloc[i]['Pressure9am']+data.iloc[i]['Pressure3pm'])*0.5
    avgclouds[i]=(data.iloc[i]['Cloud9am']+data.iloc[i]['Cloud3pm'])*0.5
data['AvgTemp'] = avgtemp
data['AvgWind'] = avgwind
data['AvgHumidity'] = avghumidity
data['AvgPressure'] = avgpressure
data['AvgClouds'] = avgclouds
data.drop(labels=['Temp3pm','Temp9am','WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
                   'Humidity3pm',  'Pressure9am',  'Pressure3pm', 'Cloud9am', 'Cloud3pm'], inplace=True, axis=1)
data
# Out:
#        MinTemp  MaxTemp  Rainfall  WindGustSpeed  RainToday  AvgTemp  AvgWind  \
# 0         13.4     22.9       0.6           44.0        0.0    19.35     22.0
# 1          7.4     25.1       0.0           44.0        0.0    20.75     13.0
# 2         17.5     32.3       1.0           41.0        0.0    23.75     13.5
# 3         14.6     29.7       0.2           56.0        0.0    24.75     21.5
# 4          7.7     26.7       0.0           35.0        0.0    20.90     11.5
# ...        ...      ...       ...            ...        ...      ...      ...
# 41899      5.4     13.4       2.0           59.0        1.0    10.05     27.5
# 41900      2.1     13.2       2.4           30.0        1.0     8.45     15.0
# 41901      4.4     16.5       0.0           48.0        0.0    12.10     23.0
# 41902      6.1     14.5       0.4           44.0        0.0    10.30     19.5
# 41903      6.1     16.2       0.0           30.0        0.0    12.20     15.0
#
# ...

# %%
cols_to_norm = ['MinTemp', 'MaxTemp', 'WindGustSpeed', 'AvgTemp', 'AvgWind', 'AvgHumidity', 'AvgPressure', 'AvgClouds']
data[cols_to_norm] = data[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
data
# Out:
#         MinTemp   MaxTemp  Rainfall  WindGustSpeed  RainToday  AvgTemp  \
# 0      0.524422  0.454139       0.6       0.289062        0.0  0.45250
# 1      0.370180  0.503356       0.0       0.289062        0.0  0.48750
# 2      0.629820  0.664430       1.0       0.265625        0.0  0.56250
# 3      0.555270  0.606264       0.2       0.382812        0.0  0.58750
# 4      0.377892  0.539150       0.0       0.218750        0.0  0.49125
# ...         ...       ...       ...            ...        ...      ...
# 41899  0.318766  0.241611       2.0       0.406250        1.0  0.22000
# 41900  0.233933  0.237136       2.4       0.179688        1.0  0.18000
# 41901  0.293059  0.310962       0.0       0.320312        0.0  0.27125
# 41902  0.336761  0.266219       0.4       0.289062        0.0  0.22625
# 41903  0.336761  0.304251       0.0       0.179688        0.0  0.27375
#
#         AvgWind  AvgHumidity  AvgPressure  AvgClouds
# 0      0.273292     0.442708     0.465488     0.5000
# ...

# %%
data.to_csv('Normalized_data.csv')
