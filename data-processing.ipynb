# %%
import pandas as pd
import numpy as np
import seaborn as sns
import math 
import random as rn
import matplotlib.pyplot as plt

# %%
def split(x, k):  
    splitPoint = int(len(x) * k)
    return x.iloc[:splitPoint], x.iloc[splitPoint:]

def getDistances(x, sample, columnNames, function, power):
    lis = []
    for i in range(len(x)):
        y=0
        for column in columnNames:
            y+=(function(x.loc[i,column], sample[column], power))
        lis.append(y)
    return lis


def manhattan(first, second, n):
    return abs(first - second)
        

def euclides(first, second, n):
    difference = math.pow(first, n) - math.pow(second, n)
    return difference ** 1/n

def sort(x, lis):
        x['distance'] = lis
        return x.sort_values(by=['distance'])

def shuffle(x):
    for i in range(len(x) - 1, 0, -1):
        j = rn.randint(0, i - 1)
        x.iloc[i], x.iloc[j] = x.iloc[j], x.iloc[i]

def knn(recs,k):
    dict={1:0,0:0}
    knn=recs.iloc[:k]['RainTomorrow']
    for i in knn:
        if i:
            dict[1]+=1
        else:
            dict[0]+=1
    return (max(dict, key=dict.get))

def knnRain(recs,k):
    
    
    rain=recs.iloc[:k]['Rainfall']
    mean = rain.mean()
    sigm = rain.std()
  
    return mean,sigm

def knnTemp(recs,k):  
    rain=recs.iloc[:k]['AvgTemp']
    mean = rain.mean()
    sigm = rain.std()
  
    return mean,sigm

def avgTemp(x):
    lis = []
    for i in range(len(x)):
        lis.append(x.iloc[i]['Temp3pm']+x.iloc[i]['Temp9am']*0.5)
    x['AvgTemp'] = lis

# %%
data = pd.read_csv('WeatherTrainingData.csv')
data.drop(labels=['Location','Evaporation', 'WindDir9am', 'WindDir3pm' ,'WindGustDir','Sunshine','row ID' ], inplace=True, axis=1)
data["Cloud3pm"].fillna(0, inplace = True)
data["Cloud9am"].fillna(0, inplace = True)
data.replace({'RainToday': {"No": 0, 'Yes': 1}},inplace=True)
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)
data
# Out:
#        MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0         13.4     22.9       0.6           44.0          20.0          24.0
# 1          7.4     25.1       0.0           44.0           4.0          22.0
# 2         17.5     32.3       1.0           41.0           7.0          20.0
# 3         14.6     29.7       0.2           56.0          19.0          24.0
# 4          7.7     26.7       0.0           35.0           6.0          17.0
# ...        ...      ...       ...            ...           ...           ...
# 83804      8.0     20.7       0.0           41.0          19.0          26.0
# 83805      3.5     21.8       0.0           31.0          15.0          13.0
# 83806      2.8     23.4       0.0           31.0          13.0          11.0
# 83807      3.6     25.3       0.0           22.0          13.0           9.0
# 83808      5.4     26.9       0.0           37.0           9.0           9.0
#
#        Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0             71.0         22.0       1007.7       1007.1       8.0       0.0
# 1             44.0         25.0       1010.6       1007.8       0.0       0.0
# 2             82.0         33.0       1010.8       1006.0       7.0       8.0
# 3             55.0         23.0       1009.2       1005.4       0.0       0.0
# 4             48.0         19.0       1013.4       1010.1       0.0       0.0
# ...            ...          ...          ...          ...       ...       ...
# 83804         56.0         32.0       1028.1       1024.3       0.0       7.0
# 83805         59.0         27.0       1024.7       1021.2       0.0       0.0
# 83806         51.0         24.0       1024.6       1020.3       0.0       0.0
# 83807         56.0         21.0       1023.5       1019.1       0.0       0.0
# 83808         53.0         24.0       1021.0       1016.8       0.0       0.0
#
#        Temp9am  Temp3pm  RainToday  RainTomorrow
# 0         16.9     21.8        0.0             0
# 1         17.2     24.3        0.0             0
# 2         17.8     29.7        0.0             0
# 3         20.6     28.9        0.0             0
# 4         16.3     25.5        0.0             0
# ...        ...      ...        ...           ...
# 83804     11.6     20.0        0.0             0
# 83805      9.4     20.9        0.0             0
# 83806     10.1     22.4        0.0             0
# 83807     10.9     24.5        0.0             0
# 83808     12.5     26.1        0.0             0
#
# [83809 rows x 16 columns]

# %%
#data.drop(labels=['row ID' ,'WindGustSpeed',	'WindSpeed9am'	,'WindSpeed3pm',	'Humidity9am',	'Humidity3pm',	'Pressure9am',	'Pressure3pm',	'Cloud9am',	'Cloud3pm',	'Temp9am'	,'Temp3pm'	,'RainToday',	'RainTomorrow'], inplace=True, axis=1)
"""
#data=data["Temp3pm"]
data2=data[:400]
#for i in range (len(data2)):
 #   data2.iloc[i]['AvgTemp']=data2.iloc[i]['Temp3pm']+data2.iloc[i]['Temp9am']*0.5

lis = []
for i in range(len(data2)):
    lis.append(data2.iloc[i]['Temp3pm']+data2.iloc[i]['Temp9am']*0.5)
data2['AvgTemp'] = lis
sns.relplot(data=data2, x="row ID", y="AvgTemp", hue="RainToday")
plt.show()

"""
# Out:
# '\n#data=data["Temp3pm"]\ndata2=data[:400]\n#for i in range (len(data2)):\n #   data2.iloc[i][\'AvgTemp\']=data2.iloc[i][\'Temp3pm\']+data2.iloc[i][\'Temp9am\']*0.5\n\nlis = []\nfor i in range(len(data2)):\n    lis.append(data2.iloc[i][\'Temp3pm\']+data2.iloc[i][\'Temp9am\']*0.5)\ndata2[\'AvgTemp\'] = lis\nsns.relplot(data=data2, x="row ID", y="AvgTemp", hue="RainToday")\nplt.show()\n\n'

# %%
values=data.select_dtypes(exclude="object")
columnNames=values.columns.tolist()
columnNames=columnNames[:-2]
#doDeszczuIlosc
columnNames=['MinTemp',	'MaxTemp','WindGustSpeed',	'WindSpeed9am',	'WindSpeed3pm',	'Humidity9am',	'Humidity3pm',	'Pressure9am',	'Pressure3pm',	'Cloud9am',	'Cloud3pm',	'Temp9am',	'Temp3pm']
#doTemp
#columnNames=['MinTemp',	'Rainfall','MaxTemp','WindGustSpeed',	'WindSpeed9am',	'WindSpeed3pm',	'Humidity9am',	'Humidity3pm',	'Pressure9am',	'Pressure3pm',	'Cloud9am',	'Cloud3pm']

for column in columnNames:
        x=data.loc[:,column]
        min1=min(x)
        max1=max(x)
        for row in range (len(data)):
            xprim=(data.at[row,column]-min1)/(max1-min1)
            data.at[row,column]=xprim

# %%
data = data.sample(frac=1).reset_index(drop=True)#tasowanie
ts,vs=split(data,0.7)
data
# Out:
#         MinTemp   MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# 0      0.589242  0.593407  0.000000       0.224806      0.000000
# 1      0.528117  0.586813  0.000000       0.294574      0.195402
# 2      0.398533  0.432967  0.000000       0.255814      0.103448
# 3      0.520782  0.364835  0.000000       0.193798      0.149425
# 4      0.337408  0.349451  0.000000       0.124031      0.103448
# ...         ...       ...       ...            ...           ...
# 83804  0.332518  0.237363  0.000000       0.255814      0.172414
# 83805  0.366748  0.320879  0.000544       0.341085      0.195402
# 83806  0.452323  0.432967  0.003808       0.472868      0.448276
# 83807  0.217604  0.323077  0.000544       0.186047      0.000000
# 83808  0.711491  0.736264  0.000000       0.341085      0.298851
#
#        WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# 0          0.218391         0.67         0.61     0.548760     0.560261
# 1          0.195402         0.65         0.39     0.543802     0.535831
# 2          0.229885         0.61         0.29     0.545455     0.557003
# 3          0.218391         0.71         0.67     0.704132     0.690554
# 4          0.103448         0.75         0.50     0.702479     0.644951
# ...             ...          ...          ...          ...          ...
# 83804      0.068966         0.90         0.64     0.842975     0.855049
# 83805      0.195402         0.44         0.28     0.682645     0.682410
# 83806      0.425287         0.81         0.47     0.476033     0.503257
# 83807      0.172414         0.99         0.53     0.775207     0.765472
# 83808      0.275862         0.31         0.31     0.390083     0.410423
#
#        Cloud9am  Cloud3pm   Temp9am   Temp3pm  RainToday  RainTomorrow
# 0      0.000000  0.000000  0.605081  0.511111        0.0             0
# 1      0.000000  0.000000  0.503464  0.553333        0.0             0
# 2      0.000000  0.000000  0.406467  0.448889        0.0             0
# 3      0.333333  0.555556  0.473441  0.364444        0.0             0
# 4      0.111111  0.777778  0.344111  0.342222        0.0             0
# ...         ...       ...       ...       ...        ...           ...
# 83804  0.888889  0.000000  0.270208  0.235556        0.0             0
# 83805  0.777778  0.111111  0.351039  0.335556        0.0             0
# 83806  0.777778  0.777778  0.420323  0.437778        1.0             0
# 83807  0.888889  0.444444  0.304850  0.342222        0.0             0
# 83808  0.000000  0.000000  0.775982  0.688889        0.0             0
#
# [83809 rows x 16 columns]

# %%
ts=ts[:100]
vs=vs[:10]

# %%
values=data.select_dtypes(exclude="object")
columnNames=values.columns.tolist()

# %%
"""
counter = 0
for i, r in vs.iterrows():
    lis = getDistances(ts, r, columnNames, euclides, 2)
    recs = sort(ts, lis)
    if knn(recs,10)==r['RainTomorrow']:
        counter+=1
print( counter / len(vs))
"""
# Out:
# "\ncounter = 0\nfor i, r in vs.iterrows():\n    lis = getDistances(ts, r, columnNames, euclides, 2)\n    recs = sort(ts, lis)\n    if knn(recs,10)==r['RainTomorrow']:\n        counter+=1\nprint( counter / len(vs))\n"

# %%
counter = 0
for i, r in vs.iterrows():
    lis = getDistances(ts, r, columnNames, euclides, 3)
    recs = sort(ts, lis)
    d,o=knnRain(recs,10)
    
    #if d==r['Rainfall']:
    if (d-o)<=r['Rainfall'] and (d+o)>=r['Rainfall']:
        counter+=1
print( counter / len(vs))
# Out:
# 0.8

# %%
"""
counter = 0
avgTemp(ts)
avgTemp(vs)

for i, r in vs.iterrows():
    lis = getDistances(ts, r, columnNames, euclides, 2)
    recs = sort(ts, lis)
    d,o=knnTemp(recs,10)
    if (d-o)<=r['AvgTemp'] and (d+o)>=r['AvgTemp']:
    
        counter+=1
print( counter / len(vs))
"""
# Out:
# "\ncounter = 0\navgTemp(ts)\navgTemp(vs)\n\nfor i, r in vs.iterrows():\n    lis = getDistances(ts, r, columnNames, euclides, 2)\n    recs = sort(ts, lis)\n    d,o=knnTemp(recs,10)\n    if (d-o)<=r['AvgTemp'] and (d+o)>=r['AvgTemp']:\n    \n        counter+=1\nprint( counter / len(vs))\n"
